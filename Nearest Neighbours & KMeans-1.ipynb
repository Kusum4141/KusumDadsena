# %%
url='https://github.com/edyoda/data-science-complete-tutorial/blob/master/Data/house_rental_data.csv.txt'

# The above url is of the main github location for importing it, the raw view url is needed which is below

url='https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt'

# %%
# Importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math

# %%
# %matplotlib inline

# %%
# Assigning the dataset to a variable'df' as a pandas dataframe
df=pd.read_csv(url)

# %%
# Glancing at dataset
df
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0             1  1177.698      2           7        2            2         2
# 1             2  2134.800      5           7        4            2         2
# 2             3  1138.560      5           7        2            2         1
# 3             4  1458.780      2           7        3            2         2
# 4             5   967.776     11          14        3            2         2
# ..          ...       ...    ...         ...      ...          ...       ...
# 640         644  1359.156      7          15        3            2         2
# 641         645   377.148      4          10        1            1         1
# 642         646   740.064     13          14        1            1         1
# 643         647  1707.840      3          14        3            2         2
# 644         648  1376.946      6           7        3            2         1
#
#      Price
# 0    62000
# 1    78000
# 2    58000
# 3    45000
# 4    45000
# ..     ...
# 640  45000
# 641  24800
# 642  45000
# 643  65000
# 644  36000
#
# [645 rows x 8 columns]

# %%
# Setting the 
df.set_index('Unnamed: 0',inplace=True)

# %%
df
# Out:
#                 Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# Unnamed: 0
# 1           1177.698      2           7        2            2         2  62000
# 2           2134.800      5           7        4            2         2  78000
# 3           1138.560      5           7        2            2         1  58000
# 4           1458.780      2           7        3            2         2  45000
# 5            967.776     11          14        3            2         2  45000
# ...              ...    ...         ...      ...          ...       ...    ...
# 644         1359.156      7          15        3            2         2  45000
# 645          377.148      4          10        1            1         1  24800
# 646          740.064     13          14        1            1         1  45000
# 647         1707.840      3          14        3            2         2  65000
# 648         1376.946      6           7        3            2         1  36000
#
# [645 rows x 7 columns]

# %% [markdown]
# # 1. Insights into the data

# %%
rows,cols=df.shape
print('Number of rows : ',rows,'\nNumber of columns : ',cols)
# Out:
# Number of rows :  645
# Number of columns :  7

# %%
# Getting statistics of every column
df.describe()
# Out:
#               Sqft       Floor  TotalFloor     Bedroom  Living.Room  \
# count   645.000000  645.000000  645.000000  645.000000   645.000000
# mean   1527.656260    5.939535   10.855814    2.837209     1.813953
# std     767.386531    3.884721    4.996208    1.010740     0.462364
# min     359.358000    1.000000    1.000000    1.000000     0.000000
# 25%     925.080000    3.000000    7.000000    2.000000     2.000000
# 50%    1423.200000    5.000000   12.000000    3.000000     2.000000
# 75%    1892.856000    8.000000   14.000000    4.000000     2.000000
# max    5856.468000   22.000000   38.000000    7.000000     4.000000
#
#          Bathroom          Price
# count  645.000000     645.000000
# mean     1.810853   61986.823256
# std      0.683574   35635.091007
# min      0.000000    6100.000000
# 25%      1.000000   39000.000000
# 50%      2.000000   50000.000000
# 75%      2.000000   75000.000000
# max      5.000000  250000.000000

# %%
# Info of the dataframe and its columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645 entries, 1 to 648
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sqft         645 non-null    float64
#  1   Floor        645 non-null    int64
#  2   TotalFloor   645 non-null    int64
#  3   Bedroom      645 non-null    int64
#  4   Living.Room  645 non-null    int64
#  5   Bathroom     645 non-null    int64
#  6   Price        645 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 40.3 KB

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Sqft           0
# Floor          0
# TotalFloor     0
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
# Renaming a misspelt column name
df.rename({'Living.Room':'Livingroom'},axis=1,inplace=True)

# %%
df
# Out:
#                 Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom  Price
# Unnamed: 0
# 1           1177.698      2           7        2           2         2  62000
# 2           2134.800      5           7        4           2         2  78000
# 3           1138.560      5           7        2           2         1  58000
# 4           1458.780      2           7        3           2         2  45000
# 5            967.776     11          14        3           2         2  45000
# ...              ...    ...         ...      ...         ...       ...    ...
# 644         1359.156      7          15        3           2         2  45000
# 645          377.148      4          10        1           1         1  24800
# 646          740.064     13          14        1           1         1  45000
# 647         1707.840      3          14        3           2         2  65000
# 648         1376.946      6           7        3           2         1  36000
#
# [645 rows x 7 columns]

# %%
df.Price.value_counts()
# Out:
# 45000     47
# 55000     29
# 36000     25
# 50000     22
# 100000    17
#           ..
# 41999      1
# 23800      1
# 65999      1
# 67000      1
# 24800      1
# Name: Price, Length: 153, dtype: int64

# %% [markdown]
# # 2.Visualization

# %%
sns.displot(df['Price'],color='red',bins=10)

# %%
sns.pairplot(df,kind='reg')

# %%
# Comparing Sqft with Price in a jointplot with reg

sns.jointplot(x='Sqft',y='Price',data=df,kind='reg')

# %%
# Pie chart of number of floors
plt.pie(df['Floor'].value_counts(),labels=df['Floor'].value_counts().index,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # 3. Managing data for training and testing

# %%
# the dataset
df
# Out:
#                 Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom  Price
# Unnamed: 0
# 1           1177.698      2           7        2           2         2  62000
# 2           2134.800      5           7        4           2         2  78000
# 3           1138.560      5           7        2           2         1  58000
# 4           1458.780      2           7        3           2         2  45000
# 5            967.776     11          14        3           2         2  45000
# ...              ...    ...         ...      ...         ...       ...    ...
# 644         1359.156      7          15        3           2         2  45000
# 645          377.148      4          10        1           1         1  24800
# 646          740.064     13          14        1           1         1  45000
# 647         1707.840      3          14        3           2         2  65000
# 648         1376.946      6           7        3           2         1  36000
#
# [645 rows x 7 columns]

# %%
# The features
X = df.iloc[:,:6]

# The target
Y = df.iloc[:,6]

# %%
X.head()
# Out:
#                 Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom
# Unnamed: 0
# 1           1177.698      2           7        2           2         2
# 2           2134.800      5           7        4           2         2
# 3           1138.560      5           7        2           2         1
# 4           1458.780      2           7        3           2         2
# 5            967.776     11          14        3           2         2

# %%
Y.head()
# Out:
# Unnamed: 0
# 1    62000
# 2    78000
# 3    58000
# 4    45000
# 5    45000
# Name: Price, dtype: int64

# %%
# Splitting these datasets into training and testing

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=7)

# %%
# Checking splitted data
x_train
# Out:
#                 Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom
# Unnamed: 0
# 156          996.240     11          14        3           2         2
# 182         1487.244      6           7        4           2         2
# 308         1871.508     11          12        4           2         2
# 468         1227.510      2           7        3           2         2
# 235         2067.198      4          14        4           2         2
# ...              ...    ...         ...      ...         ...       ...
# 583          796.992      3          12        2           2         1
# 506         1102.980      2           4        3           1         2
# 541         1426.758      3          12        3           2         2
# 199         1732.746      8          12        4           2         2
# 178         1850.160     16          18        4           2         3
#
# [483 rows x 6 columns]

# %%
y_train
# Out:
# Unnamed: 0
# 156     44999
# 182     33700
# 308     49999
# 468     39000
# 235    100000
#         ...
# 583     45000
# 506     26000
# 541     48120
# 199     65000
# 178     82000
# Name: Price, Length: 483, dtype: int64

# %%
x_test
# Out:
#                 Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom
# Unnamed: 0
# 586         1316.460      4          15        3           2         2
# 224         2138.358     11          14        4           2         2
# 337         3558.000      1           7        3           2         2
# 71           889.500      8          12        2           1         1
# 590          800.550      3           4        2           2         1
# ...              ...    ...         ...      ...         ...       ...
# 545         1102.980      2           4        2           1         2
# 24          1668.702      4          12        3           2         2
# 276          533.700      7          12        1           1         1
# 388         1586.868      3           7        3           2         2
# 648         1376.946      6           7        3           2         1
#
# [162 rows x 6 columns]

# %%
y_test
# Out:
# Unnamed: 0
# 586     45000
# 224     55000
# 337    160000
# 71      25000
# 590     43000
#         ...
# 545     31000
# 24     105000
# 276     17000
# 388     44000
# 648     36000
# Name: Price, Length: 162, dtype: int64

# %% [markdown]
# # 4. Modelling and finding better value for k

# %%
# Modelling using a k value of 5
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_train,y_train) # fitting the model
y_pred=model.predict(x_test) # predicting values

# calculating root mean squared error (RMSE)
error = math.sqrt(mean_squared_error(y_test,y_pred))
print(error)
# Out:
# 17553.0360311293

# %%
# Finding optimal value of k so that RMSE is minimum

rmse_val=[]
for i in range(1,101):
    model=KNeighborsRegressor(n_neighbors=i)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    error=math.sqrt(mean_squared_error(y_test,y_pred))
    rmse_val.append((error,i))
print(rmse_val)
# Out:
# [(19094.499964196915, 1), (16254.242604045654, 2), (16339.124929976093, 3), (16933.678334489432, 4), (17553.0360311293, 5), (17571.10224840108, 6), (17853.111392437415, 7), (17926.09441847598, 8), (17814.124566081275, 9), (17995.774613954094, 10), (17763.809048112867, 11), (17844.15730355737, 12), (17842.146113913874, 13), (17530.912605919602, 14), (17521.11047763739, 15), (17267.6958666365, 16), (17161.16482721609, 17), (17084.2209947079, 18), (16810.246398564643, 19), (16855.809873257662, 20), (16993.842484882065, 21), (17085.593270629248, 22), (16921.247103833965, 23), (16851.03246675572, 24), (16731.00534495753, 25), (16675.310913114507, 26), (16791.162600232623, 27), (16832.118157760644, 28), (17020.47556755559, 29), (17146.13582360715, 30), (17063.250987445223, 31), (17007.829725410502, 32), (16931.463503203242, 33), (17009.04722913365, 34), (17052.426151642274, 35), (17070.325875291597, 36), (17046.057582258683, 37), (16999.747818395506, 38), (17111.147014099548, 39), (17162.19179770777, 40), (17130.22809914274, 41), (17078.755987421886, 42), (17029.5333818402, 43), (16997.443823130285, 44), (16990.784077066004, 45), (16968.45899740048, 46), (16970.925684922957, 47), (16983.0627572369, 48), (17067.67077382356, 49), (17050.881415321994, 50), (17097.22987465362, 51), (17095.314740891125, 52), (17091.00479887599, 53), (17072.091649229493, 54), (17100.61081177453, 55), (17112.69277265055, 56), (17122.98287568641, 57), (17133.50114987154, 58), (17131.27765700131, 59), (17133.229333252224, 60), (17183.38105579109, 61), (17236.69775901685, 62), (17253.921953652305, 63), (17306.817494862575, 64), (17380.206008925597, 65), (17438.334003412416, 66), (17499.03266495801, 67), (17496.962158335387, 68), (17525.731068607063, 69), (17544.304940197966, 70), (17528.888372941532, 71), (17613.268660726713, 72), (17667.48333588761, 73), (17692.71415723633, 74), (17731.57863896233, 75), (17784.28034924216, 76), (17825.942145077956, 77), (17878.027578420697, 78), (17926.09946259553, 79), (17980.87617591992, 80), (18009.913305797734, 81), (18004.724234678444, 82), (18049.506361099917, 83), (18069.45452131459, 84), (18086.55378334406, 85), (18122.612303968683, 86), (18160.704425412318, 87), (18211.615084558358, 88), (18245.499326579655, 89), (18305.438541756997, 90), (18351.269122783688, 91), (18406.645177396756, 92), (18441.006128431185, 93), (18490.147291149475, 94), (18513.40515904757, 95), (18540.230147025755, 96), (18586.634327048814, 97), (18613.82877878042, 98), (18628.894594596783, 99), (18662.146924813616, 100)]

# %%
# Getting minimum RMSE value
print(min(rmse_val))
# Out:
# (16254.242604045654, 2)

# %%
# Modelling using k value of 2
model=KNeighborsRegressor(n_neighbors=2)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
# Final predicted values
y_pred
# Out:
# array([ 43000. ,  56500. , 156500. ,  50999. ,  45000. ,  55000. ,
#         69750. ,  46500. ,  70000. ,  32250. ,  41000. ,  49900. ,
#         35000. ,  97999.5,  93950. ,  49999.5,  40000. ,  30500. ,
#         43000. , 122500. ,  29944. ,  38000. ,  45000. ,  31900. ,
#         72500. ,  47999.5,  50000. ,  93950. ,  66500. ,  56500. ,
#         30500. , 110000. , 190000. , 110000. ,  65000. ,  35500. ,
#         50999. ,  32250. ,  66500. ,  38500. ,  56500. ,  39000. ,
#         29944. ,  36000. ,  40000. ,  31500. ,  27250. ,  47500. ,
#         57000. ,  49900. ,  67500. ,  43500. , 125000. ,  49000. ,
#         72500. ,  38000. ,  55000. ,  83000. ,  77999.5,  47500. ,
#         50000. ,  66500. ,  35500. ,  30900. ,  31500. ,  40444. ,
#         60000. ,  44400. ,  85500. ,  55000. ,  72500. ,  63500. ,
#         58400. ,  46750. ,  38000. ,  70060. ,  36001. ,  95000. ,
#         31250. ,  83000. ,  72500. , 155000. , 129000. ,  56000. ,
#         58000. ,  54999.5, 100000. ,  46388.5,  42400. ,  50500. ,
#         67500. ,  41750. , 100000. ,  20501. ,  32000. ,  92499.5,
#         67500. ,  90000. ,  57000. ,  42750. ,  93950. ,  47500. ,
#         17850. ,  48444. ,  27400. ,  60000. ,  44000. ,  84000. ,
#         60000. ,  47500. ,  50500. ,  33900. ,  44000. ,  62500. ,
#         65999.5, 100000. ,  27000. ,  67500. ,  46500. ,  20501. ,
#         31250. ,  72500. ,  85000. ,  47560. ,  99999.5,  41750. ,
#         65000. ,  71500. ,  90000. ,  29400. ,  43500. ,  27400. ,
#         42400. ,  68500. ,  33900. ,  43000. , 120000. , 124000. ,
#        125000. ,  99999.5,  40250. ,  49300. ,  60500. ,  62500. ,
#         46388.5,  91500. ,  44500. ,  40500. ,  30000. ,  33000. ,
#         34900. ,  83500. ,  54999.5,  46500. ,  84944. ,  35500. ,
#         93950. ,  28500. ,  60000. ,  29399.5,  50000. ,  45900. ])
